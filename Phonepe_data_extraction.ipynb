# %%
# !pwd
# Out:
# /content

# %%
# lists the contents of the current directory
# !ls
# Out:
# sample_data

# %% [markdown]
# GitHub Cloning

# %%
# To clone the git repository, copy the github repository link
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 7975, done.
# remote: Counting objects: 100% (7975/7975), done.
# remote: Compressing objects: 100% (6637/6637), done.
# remote: Total 7975 (delta 2465), reused 6527 (delta 1031), pack-reused 0
# Receiving objects: 100% (7975/7975), 2.11 MiB | 6.79 MiB/s, done.
# Resolving deltas: 100% (2465/2465), done.

# %%
# !ls
# Out:
# pulse  sample_data

# %%
# !pwd
# Out:
# /content

# %%
# Changing the working directory to pulse
import os
os.chdir('/content/pulse')

# %%
# !ls
# Out:
# data  LICENSE  README.md

# %%
# Removing the unwanted folders or files in the directory
# !rm -rf LICENSE README.md

# %%
# Now we have only our required data folder
# !ls
# Out:
# data

# %%
import os
path = "/content/pulse/data/aggregated/transaction/country/india/state/" 
agg_trans_st_dir = os.listdir(path)
agg_trans_st_dir
# Out:
# ['madhya-pradesh',
#  'uttar-pradesh',
#  'punjab',
#  'uttarakhand',
#  'manipur',
#  'nagaland',
#  'jharkhand',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'chandigarh',
#  'chhattisgarh',
#  'goa',
#  'ladakh',
#  'andhra-pradesh',
#  'odisha',
#  'kerala',
#  'puducherry',
#  'delhi',
#  'haryana',
#  'arunachal-pradesh',
#  'tripura',
#  'maharashtra',
#  'jammu-&-kashmir',
#  'mizoram',
#  'assam',
#  'west-bengal',
#  'karnataka',
#  'gujarat',
#  'lakshadweep',
#  'tamil-nadu',
#  'sikkim',
#  'meghalaya',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'rajasthan',
#  'bihar',
#  'telangana']

# %%
for i in agg_trans_st_dir:
  st_path = path+i+'/'
  st_year = os.listdir(st_path)

# %%
import json

for i in agg_trans_st_dir:
  # /content/pulse/data/aggregated/transaction/country/india/state/haryana/
  st_path = path+i+'/'
  # st_year will show the years ['2018','2019','2020','2021','2022']
  st_year = os.listdir(st_path)
  for j in st_year:
    # /content/pulse/data/aggregated/transaction/country/india/state/haryana/2018/
    st_year_path = st_path+j+'/'
    st_year_dir = os.listdir(st_year_path)
    for k in st_year_dir:
      jsonFile = st_year_path+k
      data = open(jsonFile, 'r')
      D = json.load(data)
      print(D)
      break
# Out:
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1569868200000, 'to': 1577471400000, 'transactionData': [{'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 32083162, 'amount': 92064471161.9892}]}, {'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 19447707, 'amount': 7304157801.612935}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 16081734, 'amount': 5104821720.999016}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 127116, 'amount': 24020060.932133198}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 392270, 'amount': 190456045.32494444}]}]}, 'responseTimestamp': 1630501491309}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1601490600000, 'to': 1609093800000, 'transactionData': [{'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 67972167, 'amount': 235584201864.22342}]}, {'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 57707471, 'amount': 37315576877.14569}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 27335834, 'amount': 10977774483.325565}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 149532, 'amount': 132590450.07074244}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 487537, 'amount': 264996097.6059612}]}]}, 'responseTimestamp': 1630501493440}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1664562600000, 'to': 1672165800000, 'transactionData': [{'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count':
]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 521147, 'amount': 380139546.93821603}]}]}, 'responseTimestamp': 1630501489996}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1633026600000, 'to': 1640629800000, 'transactionData': [{'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 376584215, 'amount': 212974766412.01556}]}, {'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 331774591, 'amount': 1204991223519.016}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 66477036, 'amount': 44760398983.30789}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 298871, 'amount': 392141743.6705663}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 855060, 'amount': 639658842.8998816}]}]}, 'responseTimestamp': 1643295708555}

# %%
D['success']
# Out:
# True

# %%
D['data']['transactionData']
# Out:
# [{'name': 'Merchant payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 376584215,
#     'amount': 212974766412.01556}]},
#  {'name': 'Peer-to-peer payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 331774591,
#     'amount': 1204991223519.016}]},
#  {'name': 'Recharge & bill payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 66477036,
#     'amount': 44760398983.30789}]},
#  {'name': 'Financial Services',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 298871,
#     'amount': 392141743.6705663}]},
#  {'name': 'Others',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 855060,
#     'amount': 639658842.8998816}]}]

# %% [markdown]
# Aggregated Transaction by States

# %%
import pandas as pd

agg_trans_dict = {'State':[],
                  'Year':[],
                  'Quater':[],
                  'Transacion_type':[],
                  'Transacion_count':[],
                  'Transacion_amount':[]}

for i in agg_trans_st_dir:
  st_path = path+i+'/'
  st_year = os.listdir(st_path)
  for j in st_year:   
    st_year_path = st_path+j+'/'
    st_year_dir = os.listdir(st_year_path)
    for k in st_year_dir:
      json_path = st_year_path+k
      jsonData = open(json_path, 'r')
      Data = json.load(jsonData)
      for x in Data['data']['transactionData']:
                    Name = x['name']
                    count = x['paymentInstruments'][0]['count']
                    amount = x['paymentInstruments'][0]['amount']
                    agg_trans_dict['Transacion_type'].append(Name)
                    agg_trans_dict['Transacion_count'].append(count)
                    agg_trans_dict['Transacion_amount'].append(amount)
                    agg_trans_dict['State'].append(i)
                    agg_trans_dict['Year'].append(j)
                    agg_trans_dict['Quater'].append('Q'+k.strip('.json'))

agg_trans_df = pd.DataFrame(agg_trans_dict)
agg_trans_df
# Out:
#                State  Year Quater           Transacion_type  Transacion_count  \
# 0     madhya-pradesh  2019     Q4     Peer-to-peer payments          32083162
# 1     madhya-pradesh  2019     Q4         Merchant payments          19447707
# 2     madhya-pradesh  2019     Q4  Recharge & bill payments          16081734
# 3     madhya-pradesh  2019     Q4        Financial Services            127116
# 4     madhya-pradesh  2019     Q4                    Others            392270
# ...              ...   ...    ...                       ...               ...
# 3589       telangana  2021     Q2     Peer-to-peer payments         230861833
# 3590       telangana  2021     Q2         Merchant payments         205232899
# 3591       telangana  2021     Q2  Recharge & bill payments          58637866
# 3592       telangana  2021     Q2        Financial Services            278546
# 3593       telangana  2021     Q2                    Others            856400
#
#       Transacion_amount
# 0          9.206447e+10
# 1          7.304158e+09
# 2          5.104822e+09
# 3          2.402006e+07
# 4          1.904560e+08
# ...                 ...
# 3589       8.721520e+11
# 3590       1.232078e+11
# 3591       3.187728e+10
# 3592       3.005693e+08
# 3593       4.207234e+08
#
# [3594 rows x 6 columns]

# %%
agg_trans_df.to_csv('AggTransByStates.csv',index=False)

# %% [markdown]
#  Aggregated User by States

# %%
import os
import json
import pandas as pd

path='/content/pulse/data/aggregated/user/country/india/state/'
state_dir =os.listdir(path)

user_dict = {'State': [], 'Year': [], 'Quater': [], 'Brand': [],
    'Brand_count': [], 'Brand_percentage': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']['usersByDevice']:
          brand = x['brand']
          count = x['count']
          percentage = x['percentage']

          user_dict['Brand'].append(brand)
          user_dict['Brand_count'].append(count)
          user_dict['Brand_percentage'].append(percentage)
          user_dict['State'].append(i)
          user_dict['Year'].append(j)
          user_dict['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
userByBrand_df = pd.DataFrame(user_dict)

userByBrand_df
# Out:
#                State  Year Quater     Brand  Brand_count  Brand_percentage
# 0     madhya-pradesh  2019     Q4    Xiaomi      2450683          0.267389
# 1     madhya-pradesh  2019     Q4      Vivo      1711918          0.186784
# 2     madhya-pradesh  2019     Q4   Samsung      1704518          0.185976
# 3     madhya-pradesh  2019     Q4      Oppo      1069906          0.116735
# 4     madhya-pradesh  2019     Q4    Realme       529253          0.057746
# ...              ...   ...    ...       ...          ...               ...
# 6727       telangana  2021     Q2   OnePlus       508619          0.027783
# 6728       telangana  2021     Q2  Motorola       442262          0.024158
# 6729       telangana  2021     Q2    Huawei       380961          0.020810
# 6730       telangana  2021     Q2    Lenovo       219429          0.011986
# 6731       telangana  2021     Q2    Others      1009352          0.055135
#
# [6732 rows x 6 columns]

# %%
userByBrand_df.to_csv('userByBrand.csv',index=False)

# %% [markdown]
# Map Transaction by States

# %%
import os
import json
import pandas as pd

path='/content/pulse/data/map/transaction/hover/country/india/state/'
state_dir =os.listdir(path)


map_trans_dict = {'State': [], 'Year': [], 'Quater': [], 'District': [],
    'Transaction_count': [], 'Transaction_amount': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']["hoverDataList"]:
          district = x['name']
          trans_count = x['metric'][0]['count']
          trans_amount = x['metric'][0]['amount']
          map_trans_dict['District'].append(district)
          map_trans_dict['Transaction_count'].append(trans_count)
          map_trans_dict['Transaction_amount'].append(trans_amount)
          map_trans_dict['State'].append(i)
          map_trans_dict['Year'].append(j)
          map_trans_dict['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
mapTransByDist_df = pd.DataFrame(map_trans_dict)

mapTransByDist_df
# Out:
#                 State  Year Quater                     District  \
# 0      madhya-pradesh  2019     Q4              morena district
# 1      madhya-pradesh  2019     Q4           alirajpur district
# 2      madhya-pradesh  2019     Q4              sehore district
# 3      madhya-pradesh  2019     Q4             rajgarh district
# 4      madhya-pradesh  2019     Q4            khargone district
# ...               ...   ...    ...                          ...
# 14631       telangana  2021     Q2  medchal malkajgiri district
# 14632       telangana  2021     Q2          karimnagar district
# 14633       telangana  2021     Q2          mancherial district
# 14634       telangana  2021     Q2            siddipet district
# 14635       telangana  2021     Q2             khammam district
#
#        Transaction_count  Transaction_amount
# 0                 552247        1.176653e+09
# 1                  59374        1.113752e+08
# 2                1629869        2.294178e+09
# 3                 796105        1.515872e+09
# 4                 689426        1.235838e+09
# ...                  ...                 ...
# 14631           58755991        1.028644e+11
# 14632            8548354        2.053423e+10
# 14633            6439833        1.399926e+10
# 14634            6647863        1.590315e+10
# 14635            9096326        2.377134e+10
#
# [14636 rows x 6 columns]

# %%
mapTransByDist_df.to_csv('mapTransByDist.csv',index=False)

# %% [markdown]
# Map User by States

# %%
import os
import json
import pandas as pd

path='/content/pulse/data/map/user/hover/country/india/state/'
state_dir =os.listdir(path)

mapUserDictReg = {'State': [], 'Year': [], 'Quater': [], 'District': [],
    'Registered_user': [], 'App_opening': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']["hoverData"]:
          district = x
          registeredUser =  Data['data']["hoverData"][x]["registeredUsers"]
          app_opening = Data['data']["hoverData"][x]["appOpens"]
          mapUserDictReg['District'].append(district)
          mapUserDictReg['Registered_user'].append(registeredUser)
          mapUserDictReg['App_opening'].append(app_opening)
          mapUserDictReg['State'].append(i)
          mapUserDictReg['Year'].append(j)
          mapUserDictReg['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
mapUserByDistReg_df = pd.DataFrame(mapUserDictReg)

mapUserByDistReg_df
# Out:
#                 State  Year Quater                     District  \
# 0      madhya-pradesh  2019     Q4              morena district
# 1      madhya-pradesh  2019     Q4           alirajpur district
# 2      madhya-pradesh  2019     Q4              sehore district
# 3      madhya-pradesh  2019     Q4             rajgarh district
# 4      madhya-pradesh  2019     Q4            khargone district
# ...               ...   ...    ...                          ...
# 14635       telangana  2021     Q2  medchal malkajgiri district
# 14636       telangana  2021     Q2          karimnagar district
# 14637       telangana  2021     Q2          mancherial district
# 14638       telangana  2021     Q2            siddipet district
# 14639       telangana  2021     Q2             khammam district
#
#        Registered_user  App_opening
# 0               167329      3159169
# 1                21450       346159
# 2               208256      7562268
# 3               154830      4313460
# 4               160372      3603726
# ...                ...          ...
# 14635          2611159     94016405
# 14636           490218     23072270
# 14637           305137     21806217
# 14638           370224     24952714
# 14639           532589     29687134
#
# [14640 rows x 6 columns]

# %%
mapUserByDistReg_df.to_csv('mapUserByDistReg.csv',index=False)
